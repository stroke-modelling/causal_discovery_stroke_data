# %%
import pandas as pd
import numpy as np

# %%
titanic_df=pd.read_csv("https://raw.githubusercontent.com/hsma-programme/h6_1f_python_part_2/main/1f_python_programming_part_2/titanic_dataset.csv", index_col="PassengerId")
titanic_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic_df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
name_sex=titanic_df[["Name","Sex"]]
name_sex.head(10)
# Out:
#                                                           Name     Sex
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# 6                                             Moran, Mr. James    male
# 7                                      McCarthy, Mr. Timothy J    male
# 8                               Palsson, Master. Gosta Leonard    male
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
first_class=titanic_df.loc[titanic_df["Pclass"]==1]
second_class=titanic_df.loc[titanic_df["Pclass"]==2]
third_class=titanic_df.loc[titanic_df["Pclass"]==3]

second_class.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 10                  1       2
# 16                  1       2
# 18                  1       2
# 21                  0       2
# 22                  1       2
# 34                  0       2
# 42                  0       2
# 44                  1       2
# 54                  1       2
# 57                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 18                                Williams, Mr. Charles Eugene    male   NaN
# 21                                        Fynney, Mr. Joseph J    male  35.0
# 22                                       Beesley, Mr. Lawrence    male  34.0
# 34                                       Wheadon, Mr. Edward H    male  66.0
# ...

# %%
female_children=titanic_df.loc[(titanic_df["Sex"]=="female")&(titanic_df["Age"]<=16)]
female_children.sort_values(by=["Age","Pclass"],inplace=True)
female_children
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 470                 1       3             Baclini, Miss. Helene Barbara
# 645                 1       3                    Baclini, Miss. Eugenie
# 173                 1       3              Johnson, Miss. Eleanor Ileen
# 382                 1       3               Nakid, Miss. Maria ("Mary")
# 298                 0       1              Allison, Miss. Helen Loraine
# 531                 1       2                  Quick, Miss. Phyllis May
# 120                 0       3         Andersson, Miss. Ellis Anna Maria
# 206                 0       3                Strom, Miss. Telma Matilda
# 480                 1       3                  Hirvonen, Miss. Hildur E
# 643                 0       3             Skoog, Miss. Margit Elizabeth
# 44                  1       2  Laroche, Miss. Simonne Marie Anne Andree
# 375                 0       3                Palsson, Miss. Stina Viola
# ...

# %%
titanic_df.drop(["Name","Ticket","Cabin"],axis=1,inplace=True)
titanic_df.head(10)
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500        S
# 2                   1       1  female  38.0      1      0  71.2833        C
# 3                   1       3  female  26.0      0      0   7.9250        S
# 4                   1       1  female  35.0      1      0  53.1000        S
# 5                   0       3    male  35.0      0      0   8.0500        S
# 6                   0       3    male   NaN      0      0   8.4583        Q
# 7                   0       1    male  54.0      0      0  51.8625        S
# 8                   0       3    male   2.0      3      1  21.0750        S
# 9                   1       3  female  27.0      0      2  11.1333        S
# 10                  1       2  female  14.0      1      0  30.0708        C

# %%
titanic_df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic_df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
passenger_class=pd.pivot_table(data=titanic_df, index="Pclass", values=["Age","SibSp","Fare"],aggfunc="mean")
passenger_class
# Out:
#               Age       Fare     SibSp
# Pclass
# 1       38.233441  84.154687  0.416667
# 2       29.877630  20.662183  0.402174
# 3       25.140620  13.675550  0.615071

# %%
embark_fare=pd.pivot_table(data=titanic_df, index="Embarked",values="Fare",aggfunc="median")
embark_fare
# Out:
#            Fare
# Embarked
# C         29.70
# Q          7.75
# S         13.00
